# %%
# %matplotlib inline

from matplotlib import pyplot as plt
from matplotlib import ticker as tick
# import numpy as np
# import pandas as pd
# import statsmodels.stats.proportion as smp
# import math
from scipy.stats import beta as beta
# from sklearn.linear_model import LinearRegression

# from itertools import count as itercnt


# import sys
# import pickle
# np.set_printoptions(threshold=sys.maxsize)

# import mpmath

# import glob
# import json

# from mpmath import *

# %%
steane_str = """
0 Probability 0.0825404 stats:  num runs: 900  time: 0.815895  Mean: 1.01333 ~ 0.986842 logical  std deviation: 0.0337966  Median: 0
0.815956 Probability 0.0681292 stats:  num runs: 900  time: 0.813957  Mean: 0.99 ~ 1.0101 logical  std deviation: 0.100389  Median: 0
1.62995 Probability 0.0562341 stats:  num runs: 900  time: 0.825957  Mean: 1.06111 ~ 0.942408 logical  std deviation: 0.0646656  Median: 1
2.45595 Probability 0.0464159 stats:  num runs: 900  time: 0.802029  Mean: 0.982222 ~ 1.0181 logical  std deviation: 0.400815  Median: 0
3.25802 Probability 0.0383119 stats:  num runs: 900  time: 0.79688  Mean: 0.976667 ~ 1.02389 logical  std deviation: 0.0341301  Median: 1
4.05494 Probability 0.0316228 stats:  num runs: 900  time: 1.6521  Mean: 0.946667 ~ 1.05634 logical  std deviation: 0.00177877  Median: 0
5.70709 Probability 0.0261016 stats:  num runs: 900  time: 0.79731  Mean: 1.00222 ~ 0.997783 logical  std deviation: 0.0999815  Median: 1
6.50444 Probability 0.0215443 stats:  num runs: 900  time: 0.788454  Mean: 0.987778 ~ 1.01237 logical  std deviation: 0.0329442  Median: 1
7.29294 Probability 0.0177828 stats:  num runs: 900  time: 0.803968  Mean: 1.09222 ~ 0.915565 logical  std deviation: 0.00307578  Median: 1
8.09694 Probability 0.014678 stats:  num runs: 900  time: 0.806606  Mean: 1.18 ~ 0.847458 logical  std deviation: 0.0273485  Median: 1
8.90359 Probability 0.0121153 stats:  num runs: 900  time: 0.8053  Mean: 1.32 ~ 0.757576 logical  std deviation: 0.0106726  Median: 1
9.70893 Probability 0.01 stats:  num runs: 900  time: 0.81116  Mean: 1.49444 ~ 0.669145 logical  std deviation: 0.0502131  Median: 1
10.5201 Probability 0.00825404 stats:  num runs: 900  time: 0.793332  Mean: 1.83 ~ 0.546448 logical  std deviation: 0.0610339  Median: 1
11.3135 Probability 0.00681292 stats:  num runs: 900  time: 0.786388  Mean: 2.28889 ~ 0.436893 logical  std deviation: 0.00963498  Median: 2
12.0999 Probability 0.00562341 stats:  num runs: 900  time: 0.788966  Mean: 3.09222 ~ 0.323392 logical  std deviation: 0.00307578  Median: 2
12.8889 Probability 0.00464159 stats:  num runs: 900  time: 0.788969  Mean: 3.92 ~ 0.255102 logical  std deviation: 0.0306837  Median: 3
13.6779 Probability 0.00383119 stats:  num runs: 900  time: 0.796952  Mean: 5.28111 ~ 0.189354 logical  std deviation: 1.41538  Median: 3
14.4749 Probability 0.00316228 stats:  num runs: 900  time: 0.80997  Mean: 7.69111 ~ 0.13002 logical  std deviation: 3.47359  Median: 5
111126 Probability 1.77828e-07 stats:  num runs: 900  time: 74963.2  Mean: 1.3757e+09 ~ 7.26904e-10 logical  std deviation: 1.44384e+09  Median: 9.24749e+08
186090 Probability 1.4678e-07 stats:  num runs: 900  time: 117480  Mean: 2.20627e+09 ~ 4.53253e-10 logical  std deviation: 2.1863e+09  Median: 1.56365e+09
303570 Probability 1.21153e-07 stats:  num runs: 900  time: 173582  Mean: 3.16271e+09 ~ 3.16185e-10 logical  std deviation: 3.47839e+09  Median: 2.07879e+09
477152 Probability 1e-07 stats:  num runs: 900  time: 240384  Mean: 4.50327e+09 ~ 2.22061e-10 logical  std deviation: 4.31418e+09  Median: 3.24464e+09
"""

fifteen_seven_str = """
0 Probability 0.0681292 stats:  num runs: 900  time: 1.58155  Mean: 0.00888889 ~ 112.5 logical  std deviation: 0.000296461  Median: 0
1.58163 Probability 0.0464159 stats:  num runs: 900  time: 0.808996  Mean: 0.0111111 ~ 90 logical  std deviation: 0.000370576  Median: 0
2.3907 Probability 0.0316228 stats:  num runs: 900  time: 0.788876  Mean: 0.00777778 ~ 128.571 logical  std deviation: 0.000259403  Median: 0
3.17964 Probability 0.0215443 stats:  num runs: 900  time: 0.787935  Mean: 0.00444444 ~ 225 logical  std deviation: 0.000148231  Median: 0
3.96763 Probability 0.014678 stats:  num runs: 900  time: 0.78194  Mean: 0.00444444 ~ 225 logical  std deviation: 0.000148231  Median: 0
4.74962 Probability 0.01 stats:  num runs: 900  time: 0.792913  Mean: 0.0111111 ~ 90 logical  std deviation: 0.000370576  Median: 0
5.54258 Probability 0.00681292 stats:  num runs: 900  time: 0.780061  Mean: 0.0177778 ~ 56.25 logical  std deviation: 0.000592922  Median: 0
6.3227 Probability 0.00464159 stats:  num runs: 900  time: 0.796868  Mean: 0.0611111 ~ 16.3636 logical  std deviation: 0.00203817  Median: 0
7.11963 Probability 0.00316228 stats:  num runs: 900  time: 0.778158  Mean: 0.201111 ~ 4.97238 logical  std deviation: 0.0266444  Median: 0
7.89785 Probability 0.00215443 stats:  num runs: 900  time: 0.776828  Mean: 0.464444 ~ 2.15311 logical  std deviation: 0.0154901  Median: 0
8.67474 Probability 0.0014678 stats:  num runs: 900  time: 1.52368  Mean: 0.982222 ~ 1.0181 logical  std deviation: 0.0339448  Median: 1
10.1985 Probability 0.001 stats:  num runs: 900  time: 0.798021  Mean: 2.05333 ~ 0.487013 logical  std deviation: 0.00177877  Median: 1
10.9966 Probability 0.000681292 stats:  num runs: 900  time: 1.5549  Mean: 3.58 ~ 0.27933 logical  std deviation: 0.1194  Median: 2
12.5516 Probability 0.000464159 stats:  num runs: 900  time: 1.53426  Mean: 7.00333 ~ 0.142789 logical  std deviation: 2.82922  Median: 5
14.0859 Probability 0.000316228 stats:  num runs: 900  time: 2.30386  Mean: 14.25 ~ 0.0701754 logical  std deviation: 9.38279  Median: 9
16.3899 Probability 0.000215443 stats:  num runs: 900  time: 2.38152  Mean: 28.9878 ~ 0.0344973 logical  std deviation: 24.3926  Median: 20
18.7715 Probability 0.00014678 stats:  num runs: 900  time: 2.37572  Mean: 63.4556 ~ 0.0157591 logical  std deviation: 59.3374  Median: 44
21.1473 Probability 0.0001 stats:  num runs: 900  time: 1.72539  Mean: 132.343 ~ 0.0075561 logical  std deviation: 133.447  Median: 89
22.8728 Probability 6.81292e-05 stats:  num runs: 900  time: 2.77754  Mean: 275.559 ~ 0.00362899 logical  std deviation: 279.01  Median: 189
25.6505 Probability 4.64159e-05 stats:  num runs: 900  time: 2.43495  Mean: 569.098 ~ 0.00175717 logical  std deviation: 639.21  Median: 378
28.0855 Probability 3.16228e-05 stats:  num runs: 900  time: 4.20146  Mean: 1240.13 ~ 0.000806369 logical  std deviation: 1311.76  Median: 834
32.2872 Probability 2.15443e-05 stats:  num runs: 900  time: 6.70294  Mean: 2790.82 ~ 0.000358317 logical  std deviation: 2954.56  Median: 1845
38.9903 Probability 1.4678e-05 stats:  num runs: 900  time: 11.0921  Mean: 6171.62 ~ 0.000162032 logical  std deviation: 6158.91  Median: 4378
50.0824 Probability 1e-05 stats:  num runs: 900  time: 21.3735  Mean: 12101.7 ~ 8.2633e-05 logical  std deviation: 13044.8  Median: 8320
71.4561 Probability 6.81292e-06 stats:  num runs: 900  time: 45.7427  Mean: 27130.5 ~ 3.68589e-05 logical  std deviation: 28411  Median: 18477
117.199 Probability 4.64159e-06 stats:  num runs: 900  time: 100.695  Mean: 58822.9 ~ 1.70002e-05 logical  std deviation: 60972.1  Median: 38662
217.894 Probability 3.16228e-06 stats:  num runs: 900  time: 200.263  Mean: 122856 ~ 8.13963e-06 logical  std deviation: 124225  Median: 82600
418.158 Probability 2.15443e-06 stats:  num runs: 900  time: 469.152  Mean: 266126 ~ 3.75762e-06 logical  std deviation: 277440  Median: 173329
887.31 Probability 1.4678e-06 stats:  num runs: 900  time: 981.201  Mean: 573817 ~ 1.74272e-06 logical  std deviation: 588827  Median: 390930
1868.51 Probability 1e-06 stats:  num runs: 900  time: 2087.29  Mean: 1.19388e+06 ~ 8.37605e-07 logical  std deviation: 1.18474e+06  Median: 834570
3955.8 Probability 6.81292e-07 stats:  num runs: 900  time: 4543.41  Mean: 2.80758e+06 ~ 3.56178e-07 logical  std deviation: 2.99996e+06  Median: 1.91806e+06
8499.21 Probability 4.64159e-07 stats:  num runs: 900  time: 9491.49  Mean: 5.6015e+06 ~ 1.78524e-07 logical  std deviation: 5.71248e+06  Median: 3.74587e+06
17990.7 Probability 3.16228e-07 stats:  num runs: 900  time: 21374.3  Mean: 1.30094e+07 ~ 7.68675e-08 logical  std deviation: 1.23975e+07  Median: 9.25331e+06
39365 Probability 2.15443e-07 stats:  num runs: 900  time: 44182.7  Mean: 2.64054e+07 ~ 3.7871e-08 logical  std deviation: 2.78566e+07  Median: 1.76914e+07
83547.7 Probability 1.4678e-07 stats:  num runs: 900  time: 94446.6  Mean: 5.57948e+07 ~ 1.79228e-08 logical  std deviation: 5.68449e+07  Median: 3.90599e+07
177994 Probability 1e-07 stats:  num runs: 900  time: 202214  Mean: 1.21696e+08 ~ 8.21721e-09 logical  std deviation: 1.23131e+08  Median: 8.07949e+07
380208 Probability 6.81292e-08 stats:  num runs: 900  time: 449807  Mean: 2.64482e+08 ~ 3.78098e-09 logical  std deviation: 2.69432e+08  Median: 1.74235e+08
"""

# %%
print(beta.interval(0.997,125,162.06))
# Out:
# (0.35035221353839097, 0.5228738825298667)

# %%
steane_lines = steane_str.splitlines()[1:]
steane_data = {}
for line in steane_lines:
    split_line = line.split()
    data = {'probability': float(split_line[2]),
            'num_runs': int(split_line[6]),
            'time': float(split_line[8]),
            'mean': float(split_line[10]),
            'prob_estimator': float(split_line[12]),
            'std_deviation': float(split_line[16]),
            'median':float(split_line[18])}
    steane_data[data['probability']] = data
p_p7 = sorted(steane_data.keys())
p_l7 = [steane_data[p]['prob_estimator'] for p in p_p7]
p_ci = [beta.interval(0.997,steane_data[p]['num_runs'] + 1,steane_data[p]['num_runs']*steane_data[p]['mean'] + 1) for p in p_p7]
p_bel7 = [beta.mean(steane_data[p]['num_runs'] + 1,steane_data[p]['num_runs']*steane_data[p]['mean'] + 1) for p in p_p7]
p_yerrs = np.transpose(np.array([(p_bel7[i] - p_ci[i][0],p_ci[i][1] - p_bel7[i]) for i in range(len(p_p7))]))

# %%
p_p7e = np.geomspace(2E-2, 1E-7, 100)

estimating_polynomial = np.array([0,0,2.23E+04,-2.70E+06,1.40E+08,-3.00E+09]); #estimator for maximum likelihood
p_l7e = [np.polyval(np.flip(estimating_polynomial), i) for i in p_p7e]

estimating_polynomial2 = np.array([0,0,2.23E+04, -3.5E6, 1.7E8]); #estimator for Baysean prior of uniform distribution.
p_l7e2 = [np.polyval(np.flip(estimating_polynomial2), i) for i in p_p7e]

fig, ((ax1)) = plt.subplots(1, 1)
# With errorbars: clip non-positive values
# Use new data for plotting




ax1.set_xscale("log", nonpositive='clip')
ax1.set_yscale("log", nonpositive='clip')

ax1.plot(p_p7e, p_l7e2, label="estimating polynomial")
# ax1.plot(p_p7, p_l7, label="7-1 code logical rate Maximum Likliyhood Estimator")
# ax1.plot(p_p7, p_bel7, label="7-1 code logical rate Baysean Estimator")
plt.errorbar(p_p7, p_bel7, yerr=p_yerrs, label="7-1 code logical rate Baysean Estimator", fmt='-',capsize=4, capthick=1)
ax1.plot(p_p7, p_p7, label="break even")
ax1.grid(True, which="both", ls="-")
ax1.set_ylim(bottom=1E-11)
plt.legend()
fig = plt.gcf()
fig.set_size_inches(10,10)
fig.tight_layout()

fig.savefig('paper_images/steane_graph.pdf')

# %%
fifteen_seven_lines = fifteen_seven_str.splitlines()[1:]
fifteen_seven_data = {}
for line in fifteen_seven_lines:
    split_line = line.split()
    data = {'probability': float(split_line[2]),
            'num_runs': int(split_line[6]),
            'time': float(split_line[8]),
            'mean': float(split_line[10]),
            'prob_estimator': float(split_line[12]),
            'std_deviation': float(split_line[16]),
            'median':float(split_line[18])}
    fifteen_seven_data[data['probability']] = data
p_p_157 = sorted(fifteen_seven_data.keys())
p_l_157 = [fifteen_seven_data[p]['prob_estimator'] for p in p_p_157]
p_ci_157 = [beta.interval(0.997,fifteen_seven_data[p]['num_runs'] + 1,fifteen_seven_data[p]['num_runs']*fifteen_seven_data[p]['mean'] + 1) for p in p_p_157]
p_bel157 = [beta.mean(fifteen_seven_data[p]['num_runs'] + 1,fifteen_seven_data[p]['num_runs']*fifteen_seven_data[p]['mean'] + 1) for p in p_p_157]
p_yerrs157 = np.transpose(np.array([(p_bel157[i] - p_ci_157[i][0],p_ci_157[i][1] - p_bel157[i]) for i in range(len(p_p_157))]))
print(p_yerrs157[0]/p_bel157)
# Out:
# [0.09598726 0.09598717 0.09598718 0.09598718 0.09598718 0.09598717
#  0.09598716 0.09598714 0.09598709 0.09598701 0.09598682 0.09598643
#  0.09598556 0.09598355 0.09598006 0.09597144 0.09595177 0.09591007
#  0.09582815 0.09565699 0.09530256 0.09450824 0.0930519  0.09029428
#  0.08573955 0.08001908 0.06954741 0.056676   0.0423779  0.02642753
#  0.01622265 0.0136695  0.010195   0.010195   0.01210747 0.0136695
#  0.01265784]

# %%
# p_p_157 = [0.0014678, 0.001, 0.000681292, 0.000464159, 0.000316228, 0.000215443, 0.00014678, 0.0001, 6.81E-05, 4.64E-05, 3.16E-05, 2.15E-05, 1.47E-05, 1.00E-05, 6.81E-06, 4.64E-06, 3.16E-06, 2.15E-06, 1.47E-06, 1.00E-06, 6.81E-07, 4.64E-07, 3.16E-07, 2.15E-07, 1.47E-07, 1.00E-07, 6.81E-08]
# p_l_157 = [1.0181, 0.487013, 0.27933, 0.142789, 0.0701754, 0.0344973, 0.0157591, 0.0075561, 0.00362899, 0.00175717, 0.000806369, 0.000358317, 0.000162032, 8.26E-05, 3.69E-05, 1.70E-05, 8.14E-06, 3.76E-06, 1.74E-06, 8.38E-07, 3.56E-07, 1.79E-07, 7.69E-08, 3.79E-08, 1.79E-08, 8.22E-09, 3.78E-09]

p_p157e = np.geomspace(0.33E-2, 6.81E-08, 100)
estimating_poly_157 = [0,0,8.00E+05,-6.00E+08, 14E10]
p_l_157e = [np.polyval(np.flip(estimating_poly_157), i) for i in p_p157e]

fig, ((ax1)) = plt.subplots(1, 1)
# With errorbars: clip non-positive values
# Use new data for plotting


ax1.set_xscale("log", nonpositive='clip')
ax1.set_yscale("log", nonpositive='clip')

# ax1.plot(p_p_157, p_l_157, label="15-7 code logical rate")
ax1.plot(p_p_157, p_p_157, label="break even")
plt.errorbar(p_p_157, p_bel157, yerr=p_yerrs157, label="15-7 code logical rate Baysean Estimator", fmt='-',capsize=4, capthick=1)
ax1.plot(p_p157e, p_l_157e, label="estimate")
ax1.grid(True, which="both", ls="-")
ax1.set_ylim(bottom=1E-10)
plt.legend()
fig = plt.gcf()
fig.set_size_inches(10,10)
fig.tight_layout()

fig.savefig('paper_images/fifteen_seven_graph.pdf')
